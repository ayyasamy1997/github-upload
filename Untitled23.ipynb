# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
dataset = pd.read_csv('/Salary_Data.csv')
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X = dataset.iloc[:, :-1].values  #independent variable array
y = dataset.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=1/3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# predicting the test set results
y_pred = regressor.predict(X_test) 
y_pred
# Out:
# array([ 40835.10590871, 123079.39940819,  65134.55626083,  63265.36777221,
#        115602.64545369, 108125.8914992 , 116537.23969801,  64199.96201652,
#         76349.68719258, 100649.1375447 ])

# %%
y_test
# Out:
# array([ 37731., 122391.,  57081.,  63218., 116969., 109431., 112635.,
#         55794.,  83088., 101302.])

# %%
plt.scatter(X_train, y_train, color='red') # plotting the observation line
plt.plot(X_train, regressor.predict(X_train), color='blue') # plotting the regression line
plt.title("Salary vs Experience (Training set)") # stating the title of the graph
  
plt.xlabel("Years of experience") # adding the name of x-axis
plt.ylabel("Salaries") # adding the name of y-axis
plt.show() # specifies end of graph

# %%
plt.scatter(X_test, y_test, color='red') 
plt.plot(X_train, regressor.predict(X_train), color='blue') # plotting the regression line
plt.title("Salary vs Experience (Testing set)")
  
plt.xlabel("Years of experience") 
plt.ylabel("Salaries") 
plt.show()

# %%
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
dataset = dataset[~dataset.Salary.isnull()].copy()

# Checking the missing values in the dataset.
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
month_mode = dataset.YearsExperience.mode()[0]

# Fill the missing values with mode value of month in data.
dataset.YearsExperience.fillna(month_mode, inplace = True)

# Let's see the null values in the month column.
dataset.YearsExperience.isnull().sum()
# Out:
# 0

# %%
dataset.YearsExperience.value_counts(normalize=True)

#plot the bar graph of percentage job categories
dataset.YearsExperience.value_counts(normalize=True).plot.barh()
plt.show()

# %%
dataset.Salary.value_counts(normalize=True)

#plot the bar graph of percentage job categories
dataset.Salary.value_counts(normalize=True).plot.barh()
plt.show()

# %%
dataset.Salary.value_counts(normalize=True)

#plot the pie chart of education categories
dataset.Salary.value_counts(normalize=True).plot.pie()
plt.show()

# %%
dataset.Salary.describe()
# Out:
# count        30.000000
# mean      76003.000000
# std       27414.429785
# min       37731.000000
# 25%       56720.750000
# 50%       65237.000000
# 75%      100544.750000
# max      122391.000000
# Name: Salary, dtype: float64

# %%
plt.scatter(dataset.Salary,dataset.YearsExperience)
plt.show()

# %%
#plot the scatter plot of balance and age variable in data
dataset.plot.scatter(x="Salary",y="YearsExperience")
plt.show()

# %%
dataset[['Salary','YearsExperience']].corr()

#plot the correlation matrix of salary, balance and age in data dataframe.
sns.heatmap(dataset[['Salary','YearsExperience']].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
dataset.groupby('YearsExperience')['Salary'].mean()
# Out:
# YearsExperience
# 1.1      39343.0
# 1.3      46205.0
# 1.5      37731.0
# 2.0      43525.0
# 2.2      39891.0
# 2.9      56642.0
# 3.0      60150.0
# 3.2      59445.0
# 3.7      57189.0
# 3.9      63218.0
# 4.0      56375.5
# 4.1      57081.0
# 4.5      61111.0
# 4.9      67938.0
# 5.1      66029.0
# 5.3      83088.0
# 5.9      81363.0
# 6.0      93940.0
# 6.8      91738.0
# 7.1      98273.0
# 7.9     101302.0
# 8.2     113812.0
# 8.7     109431.0
# 9.0     105582.0
# 9.5     116969.0
# 9.6     112635.0
# 10.3    122391.0
# 10.5    121872.0
# Name: Salary, dtype: float64

# %%
dataset.groupby('YearsExperience')['Salary'].median()
# Out:
# YearsExperience
# 1.1      39343.0
# 1.3      46205.0
# 1.5      37731.0
# 2.0      43525.0
# 2.2      39891.0
# 2.9      56642.0
# 3.0      60150.0
# 3.2      59445.0
# 3.7      57189.0
# 3.9      63218.0
# 4.0      56375.5
# 4.1      57081.0
# 4.5      61111.0
# 4.9      67938.0
# 5.1      66029.0
# 5.3      83088.0
# 5.9      81363.0
# 6.0      93940.0
# 6.8      91738.0
# 7.1      98273.0
# 7.9     101302.0
# 8.2     113812.0
# 8.7     109431.0
# 9.0     105582.0
# 9.5     116969.0
# 9.6     112635.0
# 10.3    122391.0
# 10.5    121872.0
# Name: Salary, dtype: float64

# %%
sns.boxplot(dataset.YearsExperience, dataset.Salary)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
